# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import h5py
import os
import matplotlib.pyplot as plt
import pandas as pd

import scipy 
import scipy.fftpack
import seaborn as sns

from scipy.fft import fft, ifft
from scipy import signal

from scipy import stats

# %%
os.chdir("C:/Users/celie/OneDrive - ugentbe/NOG NODIG/2de master/Masterproef/Wilson Cowan/DATA/shortDATA/S100")

#import healthy Q = 1 data    = model with same parameters in all regions
filename = "Health_seed100-1.h5"

with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])
    datatime = list(f['time'])

H1 = np.array(datapoints)
time = np.array(datatime)


filename = "Health_seed100-2.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])
H2 = np.array(datapoints)


filename = "Health_seed100-3.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])
H3 = np.array(datapoints)
timed100_3 = np.array(datatime)


filename = "Health_seed100-4.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])
H4 = np.array(datapoints)


filename = "Health_seed100-5.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])

H5 = np.array(datapoints)

filename = "Health_seed100-6.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])

H6 = np.array(datapoints)

filename = "Health_seed100-7.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])

H7 = np.array(datapoints)

filename = "Health_seed100-8.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])
H8 = np.array(datapoints)

filename = "Health_seed100-9.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])

H9 = np.array(datapoints)

filename = "Health_seed100-10.h5"
with h5py.File(filename, "r") as f:
    a_group_key = list(f.keys())[0]
    datapoints = list(f['data'])

H10 = np.array(datapoints)


########DEPRESSED###########
filename = "D_1.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D1 = np.array(datapoints)

filename = "D_2.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D2 = np.array(datapoints)

filename = "D_3.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D3 = np.array(datapoints)

filename = "D_4.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D4 = np.array(datapoints)

filename = "D_5.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D5 = np.array(datapoints)

filename = "D_6.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D6 = np.array(datapoints)

filename = "D_7.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D7 = np.array(datapoints)

filename = "D_8.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D8 = np.array(datapoints)

filename = "D_9.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D9 = np.array(datapoints)

filename = "D_10.h5"
with h5py.File(filename, "r") as f: a_group_key = list(f.keys())[0]; datapoints = list(f['data'])
D10 = np.array(datapoints)

# %%
os.chdir("C:/Users/celie/OneDrive - ugentbe/NOG NODIG/2de master/Masterproef/Wilson Cowan/DATA")
#import connectivity file to know which region corresponds to which index in the matrices
filename = "Connectivity.h5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    regions_list = list(f['region_labels'])

regions = np.array(regions_list)
#make selection of regions to loop through 
indices = [*range(0,76 , 1)] #[13,15,16,18,21,35,36,51,53,54,56,59,73,74]
#create list of indices per hemisphere
Lhem_ind = [*range(38, 76, 1)]
Rhem_ind = [*range(0, 38, 1)]
# Out:
# Keys: <KeysViewHDF5 ['areas', 'centres', 'cortical', 'hemispheres', 'orientations', 'region_labels', 'tract_lengths', 'weights']>

# %%
#select correct colomns from datasets
H1 = H1[:, 0, :, 0]
H2 = H2[:, 0, :, 0]
H3 = H3[:, 0, :, 0]
H4 = H4[:, 0, :, 0]
H5 = H5[:, 0, :, 0]
H6 = H6[:, 0, :, 0]
H7 = H7[:, 0, :, 0]
H8 = H8[:, 0, :, 0]
H9 = H9[:, 0, :, 0]
H10 = H10[:, 0, :, 0]

D1 = D1[:, 0, :, 0]
D2 = D2[:, 0, :, 0]
D3 = D3[:, 0, :, 0]
D4 = D4[:, 0, :, 0]
D5 = D5[:, 0, :, 0]
D6 = D6[:, 0, :, 0]
D7 = D7[:, 0, :, 0]
D8 = D8[:, 0, :, 0]
D9 = D9[:, 0, :, 0]
D10 = D10[:, 0, :, 0]

#delete first 500ms
list_deleterows = [*range(0,500,1)]

#delete first 500 rows from all datasets (both datapoints and time)
time = np.delete(time, list_deleterows, 0)
H1 = np.delete(H1, list_deleterows, 0)
H2 = np.delete(H2, list_deleterows, 0)
H3 = np.delete(H3, list_deleterows, 0)
H4 = np.delete(H4, list_deleterows, 0)
H5 = np.delete(H5, list_deleterows, 0)
H6 = np.delete(H6, list_deleterows, 0)
H7 = np.delete(H7, list_deleterows, 0)
H8 = np.delete(H8, list_deleterows, 0)
H9 = np.delete(H9, list_deleterows, 0)
H10 = np.delete(H10, list_deleterows, 0)

D1 = np.delete(D1, list_deleterows, 0)
D2 = np.delete(D2, list_deleterows, 0)
D3 = np.delete(D3, list_deleterows, 0)
D4 = np.delete(D4, list_deleterows, 0)
D5 = np.delete(D5, list_deleterows, 0)
D6 = np.delete(D6, list_deleterows, 0)
D7 = np.delete(D7, list_deleterows, 0)
D8 = np.delete(D8, list_deleterows, 0)
D9 = np.delete(D9, list_deleterows, 0)
D10 = np.delete(D10, list_deleterows, 0)

# %%
#important variables of dataset
sample_period = 0.0009765625 #seconds
sf = 1/sample_period #sampling frequency 
sample_rate = 1024
print(sf)

#sns.set(font_scale=1.2)
dt = 0.01
t = time
# Out:
# 1024.0

# %%
list_ofdata = (H1, H2, H3, H4, H5, H6, H7, H8, H9, H10)
list_ofdepr = (D1, D2, D3, D4, D5, D6, D7, D8, D9, D10)
mydir = "C:/Users/celie/OneDrive - ugentbe/NOG NODIG/2de master/Masterproef/Wilson Cowan/Figures/Coherence/Output"

c1 = np.repeat("", 1)
c2 = np.repeat("",1)
cRest = numpy.zeros(shape=(1,9))
sig_array = np.column_stack([c1, c2, cRest])
sig_tot = np.column_stack([c1, c2, cRest])

sig_array_high = np.column_stack([c1, c2, cRest])
sig_tot_high = np.column_stack([c1, c2, cRest])

sig_array_lowest = np.column_stack([c1, c2, cRest])
sig_tot_lowest = np.column_stack([c1, c2, cRest])

sig_array_mid = np.column_stack([c1, c2, cRest])
sig_tot_mid = np.column_stack([c1, c2, cRest])

p_count_low = 0
p_count_high = 0
p_count_mid = 0
p_count_all = 0

indnow = [11, 12, 13, 20, 73, 74]
for ROI1 in  indices:
    for ROI2 in  indices:
        if ROI1 == ROI2:
            pass
        elif ROI1 < ROI2:
            pass 
        
        else:
            count_h = 0
            count_d = 0
            count_s = 0
            for healthy in list_ofdata:
                x = healthy[:,ROI1]
                y = healthy[:,ROI2]
                cxy, f = cohere(x, y, 256, 1. / dt)  
                cxy_all, f_all = cxy[21:32], f[21:32]
                cxy_low, f_low = cxy[21:26], f[21:26]
                cxy_high, f_high = cxy[28:32], f[28:32] #ranges nog aanpassen!
                cxy_mid, f_mid = cxy[25:29], f[25:29]
                
                if count_h == 0:
                    health_low = cxy_low
                    health_high = cxy_high
                    health_all = cxy_all
                    health_mid = cxy_mid
                else:
                    health_low = np.append(health_low, cxy_low)
                    health_high = np.append(health_high, cxy_high)
                    health_all = np.append(health_all, cxy_all)
                    health_mid = np.append(health_mid, cxy_mid)
                count_h = count_h + 1
                
            
            for depressed in list_ofdepr:
                x = depressed[:,ROI1]
                y = depressed[:,ROI2]
                cxy, f = cohere(x, y, 256, 1. / dt)  
                cxy_all, f_all = cxy[21:32], f[21:32]
                cxy_low, f_low = cxy[21:26], f[21:26]
                cxy_high, f_high = cxy[28:32], f[28:32] #ranges nog aanpassen!
                cxy_mid, f_mid = cxy[25:29], f[25:29]
            
                if count_d == 0:
                    depr_all= cxy_all
                    depr_low = cxy_low
                    depr_high = cxy_high
                    depr_mid = cxy_mid
                else:
                    tuple_low = (depr_low, cxy_low)
                    tuple_high = (depr_high, cxy_high)
                    tuple_all = (depr_all, cxy_all)
                    tuple_mid = (depr_mid, cxy_mid)
                    depr_low = np.append(depr_low, cxy_low)
                    depr_high = np.append(depr_high, cxy_high)
                    depr_all = np.append(depr_all, cxy_all)
                    depr_mid = np.append(depr_mid, cxy_mid)
                count_d = count_h + 1
            
            p_low = stats.ttest_ind(depr_low,health_low).pvalue
            p_high = stats.ttest_ind(depr_high,health_high).pvalue
            p_all = stats.ttest_ind(depr_all,health_all).pvalue
            p_mid = stats.ttest_ind(depr_mid,health_mid).pvalue
            
            if p_low <= 0.05: 
                print(str(ROI1) +  "x" + str(ROI2) + "p_low = " + str(p_low) )

                sig_array[0][0] = regions[ROI1]
                sig_array[0][1] = str(regions[ROI2])
                sig_array[0][2] = mean(depr_low)
                sig_array[0][3] = mean(health_low)
                sig_array[0][4] = std(depr_low)
                sig_array[0][5] = std(health_low)
                sig_array[0][6] = p_low
                sig_array[0][7] = ROI1
                sig_array[0][8] = ROI2
                sig_array[0][9] = min(f_low)
                sig_array[0][10] = max(f_low)

                if p_count_low == 0:
                    sig_tot[0][0] = str(regions[ROI1])
                    sig_tot[0][1] = str(regions[ROI2])
                    sig_tot[0][2] = mean(depr_low)
                    sig_tot[0][3] = mean(health_low)
                    sig_tot[0][4] = std(depr_low)
                    sig_tot[0][5] = std(health_low)
                    sig_tot[0][6] = p_low
                    sig_array[0][7] = ROI1
                    sig_array[0][8] = ROI2
                    sig_array[0][9] = min(f_low)
                    sig_array[0][10] = max(f_low)
                        #sig_tot = sig_array
                else:
                    sig_tuple = (sig_tot, sig_array)
                    sig_tot = np.vstack(sig_tuple)
                
                p_count_low = p_count_low + 1
            
            if p_high <= 0.05: 
                print(str(ROI1) +  "x" + str(ROI2) + "p_high = " + str(p_high) )

                sig_array_high[0][0] = regions[ROI1]
                sig_array_high[0][1] = str(regions[ROI2])
                sig_array_high[0][2] = mean(depr_high)
                sig_array_high[0][3] = mean(health_high)
                sig_array_high[0][4] = std(depr_high)
                sig_array_high[0][5] = std(health_high)
                sig_array_high[0][6] = p_high
                sig_array_high[0][7] = ROI1
                sig_array_high[0][8] = ROI2
                sig_array_high[0][9] = min(f_high)
                sig_array_high[0][10] = max(f_high)

                if p_count_high == 0:
                    sig_tot_high[0][0] = str(regions[ROI1])
                    sig_tot_high[0][1] = str(regions[ROI2])
                    sig_tot_high[0][2] = mean(depr_high)
                    sig_tot_high[0][3] = mean(health_high)
                    sig_tot_high[0][4] = std(depr_high)
                    sig_tot_high[0][5] = std(health_high)
                    sig_tot_high[0][6] = p_high
                    sig_tot_high[0][7] = ROI1
                    sig_tot_high[0][8] = ROI2
                    sig_array_high[0][9] = min(f_high)
                    sig_array_high[0][10] = max(f_high)
                        #sig_tot = sig_array
                else:
                    sig_tuple_high = (sig_tot_high, sig_array_high)
                    sig_tot_high = np.vstack(sig_tuple_high)
                
                p_count_high = p_count_high + 1
            
            if p_all <= 0.05: 
                print(str(ROI1) +  "x" + str(ROI2) + "p_all = " + str(p_all) )

                sig_array_lowest[0][0] = regions[ROI1]
                sig_array_lowest[0][1] = str(regions[ROI2])
                sig_array_lowest[0][2] = mean(depr_all)
                sig_array_lowest[0][3] = mean(health_all)
                sig_array_lowest[0][4] = std(depr_all)
                sig_array_lowest[0][5] = std(health_all)
                sig_array_lowest[0][6] = p_all
                sig_array_lowest[0][7] = ROI1
                sig_array_lowest[0][8] = ROI2
                sig_array_lowest[0][9] = min(f_all)
                sig_array_lowest[0][10] = max(f_all)

                if p_count_all== 0:
                    sig_tot_lowest[0][0] = str(regions[ROI1])
                    sig_tot_lowest[0][1] = str(regions[ROI2])
                    sig_tot_lowest[0][2] = mean(depr_all)
                    sig_tot_lowest[0][3] = mean(health_all)
                    sig_tot_lowest[0][4] = std(depr_all)
                    sig_tot_lowest[0][5] = std(health_all)
                    sig_tot_lowest[0][6] = p_all
                    sig_tot_lowest[0][7] = ROI1
                    sig_tot_lowest[0][8] = ROI2
                    sig_array_lowest[0][9] = min(f_all)
                    sig_array_lowest[0][10] = max(f_all)
                        #sig_tot = sig_array
                else:
                    sig_tuple_lowest = (sig_tot_lowest, sig_array_lowest)
                    sig_tot_lowest = np.vstack(sig_tuple_lowest)
                
                p_count_all = p_count_all + 1
                
            
            if p_mid <= 0.05: 
                print(str(ROI1) +  "x" + str(ROI2) + "p_mid = " + str(p_mid) )

                sig_array_mid[0][0] = regions[ROI1]
                sig_array_mid[0][1] = str(regions[ROI2])
                sig_array_mid[0][2] = mean(depr_mid)
                sig_array_mid[0][3] = mean(health_mid)
                sig_array_mid[0][4] = std(depr_mid)
                sig_array_mid[0][5] = std(health_mid)
                sig_array_mid[0][6] = p_mid
                sig_array_mid[0][7] = ROI1
                sig_array_mid[0][8] = ROI2
                sig_array_mid[0][9] = min(f_mid)
                sig_array_mid[0][10] = max(f_mid)

                if p_count_mid == 0:
                    sig_tot_mid[0][0] = str(regions[ROI1])
                    sig_tot_mid[0][1] = str(regions[ROI2])
                    sig_tot_mid[0][2] = mean(depr_mid)
                    sig_tot_mid[0][3] = mean(health_mid)
                    sig_tot_mid[0][4] = std(depr_mid)
                    sig_tot_mid[0][5] = std(health_mid)
                    sig_tot_mid[0][6] = p_mid
                    sig_tot_mid[0][7] = ROI1
                    sig_tot_mid[0][8] = ROI2
                    sig_array_mid[0][9] = min(f_mid)
                    sig_array_mid[0][10] = max(f_mid)
                        #sig_tot = sig_array
                else:
                    sig_tuple_mid = (sig_tot_mid, sig_array_mid)
                    sig_tot_mid = np.vstack(sig_tuple_mid)
                
                p_count_mid = p_count_mid + 1
                
file_name1 = mydir + "/coherence_low.csv"
outcome1 = pd.DataFrame.from_records(sig_tot)
outcome1.columns = ["ROI1", "ROI2", "mean_coh_d", "mean_coh_h", "sd_coh_d", "sd_coh_h", "p-value", "ROI1_nr","ROI2_nr", "f_min", "f_max"]
outcome1.to_csv(path_or_buf = file_name1, index = False)

file_name2 = mydir + "/coherence_high.csv"
outcome2 = pd.DataFrame.from_records(sig_tot_high)
outcome2.columns = ["ROI1", "ROI2", "mean_coh_d", "mean_coh_h", "sd_coh_d", "sd_coh_h", "p-value", "ROI1_nr","ROI2_nr", "f_min", "f_max"]
outcome2.to_csv(path_or_buf = file_name2, index = False)

file_name3 = mydir + "/coherence_all_alpha.csv"
outcome3 = pd.DataFrame.from_records(sig_tot_lowest)
outcome3.columns = ["ROI1", "ROI2", "mean_coh_d", "mean_coh_h", "sd_coh_d", "sd_coh_h", "p-value", "ROI1_nr","ROI2_nr","f_min", "f_max"]
outcome3.to_csv(path_or_buf = file_name3, index = False)

file_name4 = mydir + "/coherence_mid.csv"
outcome4 = pd.DataFrame.from_records(sig_tot_mid)
outcome4.columns = ["ROI1", "ROI2", "mean_coh_d", "mean_coh_h", "sd_coh_d", "sd_coh_h", "p-value", "ROI1_nr","ROI2_nr","f_min", "f_max"]
outcome4.to_csv(path_or_buf = file_name4, index = False)

print("done")
# Out:
# <img src="data:image/png;base64,..." width="640">
# 18x0p_mid = 0.010202335091300191
# 18x6p_low = 0.019211570728326424
# 18x9p_low = 0.04459850875180744
# 18x9p_all = 0.03938561251544193
# 18x13p_low = 0.03949731510202623
# 21x4p_mid = 0.03263252807723274
# 30x18p_mid = 0.04442046960010322
# 35x15p_low = 0.04658726924430058
# 35x33p_low = 0.0477467519533522
# 36x5p_low = 0.03380385100846019
# 36x35p_mid = 0.025499564858525166
# 46x20p_low = 0.041729389978814715
# 48x35p_low = 0.025248932460596955
# 54x18p_low = 0.02241993536009453
# 56x5p_low = 0.0031868299022314536
# 56x5p_all = 0.03400357154803832
# 56x12p_low = 0.037949475662868104
# 56x21p_low = 0.03725853739395479
# 56x31p_low = 0.04171072317083405
# 56x35p_mid = 0.036222175907566906
# 56x49p_low = 0.03990336367526315
# 56x50p_mid = 0.02641900224256748
# 57x18p_low = 0.021796987188427267
# 57x18p_all = 0.03439744138818869
# 59x5p_low = 0.047006624295376005
# 59x15p_all = 0.049810957006111226
# 59x17p_high = 0.03171388038629942
# ...

# %% [markdown]
# #expectations:
# increased alfa coherence in:
#
# frontal – temporal  (Leuchter, Li)
# frontal – occipital (Leuchter)
# frontal – parietal (Leuchter, Li)
# frontal – frontal (Li, Leuchter)

# %%
#mssn nog proberen kleuren te geven: rood als depressie>gezond, groen bij omgekeerd? En die stomme kleine labels wegkrijgen

import networkx as nx
G = nx.Graph()
data = sig_tot_lowest
G.add_nodes_from(regions)
G.nodes

rows = len(data)
for i in range(rows):
    node1 = data[i, 1]
    node2 = data[i, 2]
    weight = data[i, 3] 
    
    G.add_edge(node1, node2, weight = weight)

figure(figsize=(10, 10), dpi=80)
nx.draw_circular(G, with_labels = True)
#nx.draw(G, with_labels=True, font_weight='bold')
#H = nx.DiGraph(G)
fig_name = mydir + "/Coherence_All_alpha.png"
plt.savefig(fig_name)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
G = nx.Graph()
data = sig_tot_lowest
G.add_nodes_from(regions)
G.nodes

data = sig_tot
rows = len(data)
for i in range(rows):
    node1 = data[i, 1]
    node2 = data[i, 2]
    weight = data[i, 3] 
    
    G.add_edge(node1, node2, weight = weight)

figure(figsize=(10, 10), dpi=80)
nx.draw_circular(G, with_labels = True)
fig_name = mydir + "/Coherence_low.png"
plt.savefig(fig_name)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
G = nx.Graph()
data = sig_tot_lowest
G.add_nodes_from(regions)
G.nodes

data = sig_tot_high
rows = len(data)
for i in range(rows):
    node1 = data[i, 1]
    node2 = data[i, 2]
    weight = data[i, 3] 
    
    G.add_edge(node1, node2, weight = weight)

figure(figsize=(10, 10), dpi=80)
nx.draw_circular(G, with_labels = True)
fig_name = mydir + "/Coherence_high.png"
plt.savefig(fig_name)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
G = nx.Graph()
data = sig_tot_lowest
G.add_nodes_from(regions)
G.nodes

data = sig_tot_mid
rows = len(data)
for i in range(rows):
    node1 = data[i, 1]
    node2 = data[i, 2]
    weight = data[i, 3] 
    
    G.add_edge(node1, node2, weight = weight)

figure(figsize=(10, 10), dpi=80)
nx.draw_circular(G, with_labels = True)
fig_name = mydir + "/Coherence_mid.png"
plt.savefig(fig_name)
# Out:
# <img src="data:image/png;base64,..." width="800">
